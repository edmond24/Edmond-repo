# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score 1 = active user, 0= inactive user) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: The outcome of this will be that a free-tier customer will convert into a paying customer.

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer: The variables that makes the customer predictive are age, gender, location and profession, last login and activity score whether active or inactive.

# %% [markdown]
# #### 3. What timeframe is this data relevent for?

# %% [markdown]
# Answer: January - April 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: The hypothesis can be that there is a relationship between the use of the product by the customer and the demographics of the customer and the fact that this customer may or may not decide to convert into a paying customer.

# %% [markdown]
# ## Let's get started with our dataset

# %% [markdown]
# #### 1. Create a data dictionary

# %%
import pandas as pd
orig_data = pd.read_csv

# %%
import pandas as pd

# %% [markdown]
# |variable|Description|Type of Variable|
# |--|--|--|--|
# |var1|0=not thing 1= thing|categorical|
# |var 2|thing in unit x|continuous|

# %% [markdown]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# GRE| Graduate Record Examination | Ordinal
# GPA| Grade Point Average| continuous

# %% [markdown]
# We would like to explore the association between X and Y

# %%
orig_data = pd.read_csv ("../../project-1/assets/admissions.csv")

# %%
orig_data.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
orig_data.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %%
orig_data.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %%
orig_data.dropna(inplace = True)

# %%
data_correlation = orig_data.corr()
print data_correlation
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %% [markdown]
# #### 2. What is the outcome?

# %% [markdown]
# Answer: This shows whether the student was admitted or not based on the GPA and GRE.

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [markdown]
# Answer: The predictors/covariates are the prestige of the previous school, the GPA attended at that previous instituion, and the score obtained at the GRE.

# %% [markdown]
# #### 4. What timeframe is this data relevent for?

# %% [markdown]
# Answer: There's really no timeframe for this data and unless the admission table provides extra or relevant data over the years then timeframe may not relevant here.

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: The hypothesis here can be concluded that the decision making to admit students are based on students GRE score, GPA obtained at the previous school and how prestigious the previous school is based on some ranking system.

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [markdown]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %%
# !pwd
# Out:
# /Users/edmond_20000/Desktop/Edmond-repo/projects/unit-projects/project-1/starter-code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #matplot is used for graph


# %matplotlib inline 
#this make the graph stays on the same page

# %%
data_correlation = pd.DataFrame(np.random.exponential(size=100000))

data_correlation.plot(kind="density",
                    figsize=(10,10),
                    xlim=(-1,5))


plt.vlines(data_correlation.mean(),     # Plot black line at mean
           ymin=0, 
           ymax=1.8,
           linewidth=5.0)

plt.vlines(data_correlation.median(),   # Plot red line at median
           ymin=0, 
           ymax=1.8, 
           linewidth=2.0,
           color="red")

# %%
data_correlation.plot(kind ="density")

# %%
orig_data.plot.kde()

# %%
orig_data = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))
orig_data = orig_data.cumsum()
plt.figure(); orig_data.plot();

# %%
orig_data.plot(kind= "density", subplots ="gre")
orig_data.plot(kind= "density", subplots ="gre")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c76be90>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11c2b1d10>], dtype=object)

# %% [markdown]
# Answer: Exploratory analysis makes it easy to explore data sets by summarizing their main features in a graphical format.

# %% [markdown]
# #### 2a. What are the assumptions of the distribution of data?

# %% [markdown]
# Answer: My take on the assumptions is that the higher the gpa, gre goes up. It shows students with higher gpa usually scores higher on gre.

# %% [markdown]
# #### 2b. How will determine the distribution of your data?

# %% [markdown]
# Answer: Standard deviation will be used here particularly using the mean will help in the distribution of the data.

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [markdown]
# Answer: Outliers may lead to wrong analysis because any wrong data collection or wrong data entry will nullify the results of the analysis.

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [markdown]
# Answer: The correct way to test will be to remove their points based on their median absolute deviation. So we will calculate the median first, then calculate the median of the data then use the median to calculate the median absolute value.

# %% [markdown]
# #### 4a. What is colinearity?

# %% [markdown]
# Answer: Colinearity is related to efficiency

# %% [markdown]
# #### 4b. How will you test for colinearity?

# %% [markdown]
# Answer: You can test for colinearity by detecting the eigen values of the matrix. The closer the eigen values are to zero, will show that data is colinear.

# %%
#random variables
ps = np.random.randn(150, 5) 
#adding the correlation
corr = np.corrcoef(ps, rowvar=0)
#eigen values below
s, x = np.linalg.eig(corr)         
s
# Out:
# array([ 1.2013592 ,  1.1097707 ,  0.97914871,  0.90146089,  0.8082605 ])

# %%
noise = np.random.randn(150)                      
ps[:,4] = 2 * ps[:,0] + 3 * ps[:,2] + .5 * noise  
corr = np.corrcoef(xs, rowvar=0)
s, x = np.linalg.eig(corr)
s
# Out:
# array([ 1.2742975 ,  0.79309133,  0.83976622,  0.97020041,  1.12264454])

# %%
std_ps = (ps - ps.mean(axis=0)) / ps.std(axis=0)  
ys = std_ps.dot(v[:,0])
ys.mean(), ys.var()
# Out:
# (-4.1448326252672513e-17, 0.80478346324260486)

# %% [markdown]
# #### 5. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis 1 year from now.

# %% [markdown]
# Answer:

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model
